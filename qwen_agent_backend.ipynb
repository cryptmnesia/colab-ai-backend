# %% [markdown]
# <a href="https://colab.research.google.com/github/cryptmnesia/colab-ai-backend/blob/main/qwen_agent_backend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Install dependensi sistem (zstd untuk ekstrak file, pciutils agar GPU terdeteksi)
# !apt-get update -qq && apt-get install -y zstd pciutils -qq

# 2. Install Ollama
# !curl -fsSL https://ollama.com/install.sh | sh

# 3. Jalankan server Ollama di background
import os
import threading
import time

def run_ollama():
    os.system("ollama serve")

print("\n[+] Menjalankan server Ollama di background...")
threading.Thread(target=run_ollama, daemon=True).start()
time.sleep(5) # Jeda 5 detik biar servernya beneran nyala

# 4. Download model DeepSeek R1 7B
print("\n[+] Mendownload model DeepSeek-R1 (sekitar 4.7 GB, tunggu sebentar)...")
# !ollama pull deepseek-r1:7b

# 5. Install Ngrok
print("\n[+] Menginstall Ngrok...")
# !pip install pyngrok -q

# 6. Buka Tunnel
from pyngrok import ngrok

# --- TOKEN NGROK LU ---
ngrok.set_auth_token("3ERZeHhu72mM6VSJSOmmKz1v5QU_awCpwRaNhkvVAHupN1wR")
# ----------------------

tunnel = ngrok.connect(11434)
print("\n=====================================================")
print(f"🔥 API BASE URL LU: {tunnel.public_url}")
print("=====================================================")
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# >>> Cleaning up old version at /usr/local/lib/ollama
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# >>> NVIDIA GPU installed.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
#
# [+] Menjalankan server Ollama di background...
#
# [+] Mendownload model DeepSeek-R1 (sekitar 4.7 GB, tunggu sebentar)...
#
#
# [+] Menginstall Ngrok...
#
# ...
# 🔥 API BASE URL LU: https://politely-poster-sensation.ngrok-free.dev
# ...

# %%
import os
import threading
import time
from pyngrok import ngrok

# 1. Matikan proses Ollama dan Ngrok lama biar gak bentrok
os.system("pkill ollama")
try:
    ngrok.kill()
except:
    pass
time.sleep(2)

# 2. Buka GEMBOK CORS Ollama biar nerima request dari luar
os.environ["OLLAMA_ORIGINS"] = "*"
os.environ["OLLAMA_HOST"] = "0.0.0.0"

# 3. Jalanin ulang Ollama
def run_ollama():
    os.system("ollama serve")

print("\n[+] Menjalankan ulang Ollama dengan akses terbuka...")
threading.Thread(target=run_ollama, daemon=True).start()
time.sleep(5)

# 4. Bikin tunnel Ngrok baru
ngrok.set_auth_token("3ERZeHhu72mM6VSJSOmmKz1v5QU_awCpwRaNhkvVAHupN1wR")
tunnel = ngrok.connect(11434)

print("\n=====================================================")
print(f"🔥 API BASE URL LU (BARU): {tunnel.public_url}")
print("=====================================================")
# Out:
# [+] Menjalankan ulang Ollama dengan akses terbuka...
#
# ...
# 🔥 API BASE URL LU (BARU): https://politely-poster-sensation.ngrok-free.dev
# ...

# %%
# !ollama pull qwen2.5-coder:7b

# %%
modelfile_content = """FROM qwen2.5-coder:7b

SYSTEM \"\"\"
Kamu adalah Senior Full-Stack Developer dan Agent AI yang berfokus murni pada eksekusi teknis dan pemecahan masalah tingkat tinggi. Kamu berkomunikasi dengan sangat ringkas dan langsung pada intinya.

[STANDAR TEKNIS & ARSITEKTUR]
1. Tech Stack Utama: Laravel, React, Node.js, dan Inertia.js.
2. Database: Selalu gunakan sintaks dan optimasi khusus MySQL. Pastikan struktur relasi antar tabel terancang dengan sangat efisien.
3. UI/UX: Asumsikan gaya desain premium, minimalis, dan elegan menggunakan framework modern (seperti Tailwind CSS atau Shadcn).
4. Kode Bersih: Hindari kode duplikat. Buat komponen sekecil dan semodular mungkin.

[POLA PIKIR & MODE AGENT]
1. Berpikir Terstruktur: Sebelum memanggil alat (tools) atau menulis kode, buat rencana logis di latar belakang.
2. Otonomi: Jika berada dalam Agent Mode, eksekusi tugas secara tuntas (membaca file, membuat file, menjalankan perintah terminal) tanpa meminta izin berulang kali untuk setiap langkah kecil.

[GAYA KOMUNIKASI CLAUDE-STYLE]
1. Tanpa Basa-basi: Berikan jawaban yang fokus, padat, dan langsung berupa solusi atau blok kode.
2. Format Natural: Hindari penggunaan teks tebal (bold), daftar (lists), atau poin-poin (bullets) yang berlebihan kecuali benar-benar diperlukan untuk kejelasan. Gunakan paragraf prosa biasa untuk penjelasan.
3. Kepemilikan Kesalahan: Jika kamu membuat kesalahan dalam kode, jangan pernah meminta maaf atau memberikan pembenaran. Langsung berikan kode yang sudah diperbaiki.
4. Objektif dan Netral: Jangan menceramahi, memberikan opini, atau memberikan penilaian moral. Fokus 100% pada logika pemrograman dan arsitektur sistem.
\"\"\"
"""

# Menyimpan isi text ke dalam file bernama 'Modelfile'
with open("Modelfile", "w") as file:
    file.write(modelfile_content)
print("Modelfile berhasil dibuat!")
# Out:
# Modelfile berhasil dibuat!

# %%
# !ollama create qwen-gacor -f Modelfile
